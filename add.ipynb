# %%
import numpy as np
from keras.models import Model, Sequential
from keras.layers import Input, LSTM, Dense, RNN
from keras import layers
# Out:
# Using TensorFlow backend.

# %%
class colors:
    ok = '\033[92m'
    fail = '\033[91m'
    close = '\033[0m'

# %%
TRAINING_SIZE = 80000
DIGITS = 3
REVERSE = False
MAXLEN = DIGITS + 1 + DIGITS
chars = '0123456789+ '
RNN = layers.LSTM
HIDDEN_SIZE = 128
BATCH_SIZE = 128
LAYERS = 1

# %%
class CharacterTable(object):
    def __init__(self, chars):
        self.chars = sorted(set(chars))
        self.char_indices = dict((c, i) for i, c in enumerate(self.chars))
        self.indices_char = dict((i, c) for i, c in enumerate(self.chars))
    
    def encode(self, C, num_rows):
        x = np.zeros((num_rows, len(self.chars)))
        for i, c in enumerate(C):
            x[i, self.char_indices[c]] = 1
        return x
    
    def decode(self, x, calc_argmax=True):
        if calc_argmax:
            x = x.argmax(axis=-1)
        return "".join(self.indices_char[i] for i in x)

# %%
ctable = CharacterTable(chars)

# %%
questions_with_plus = []
expected_with_plus = []
seen_with_plus = set()
print('Generating data...')
while len(questions_with_plus) < TRAINING_SIZE:
    f = lambda: int(''.join(np.random.choice(list('0123456789')) for i in range(np.random.randint(1, DIGITS + 1))))
    a, b = f(), f()
    key = tuple(sorted((a, b)))
    if key in seen_with_plus:
        continue
    seen_with_plus.add(key)
    q = '{}+{}'.format(a, b)
    query = q + ' ' * (MAXLEN - len(q))
    ans = str(a + b)
    ans += ' ' * (DIGITS + 1 - len(ans))
    if REVERSE:
        query = query[::-1]
    questions_with_plus.append(query)
    expected_with_plus.append(ans)
print('Total addition questions:', len(questions_with_plus))
# Out:
# Generating data...
# Total addition questions: 80000

# %% [markdown]
# # Processing
# ## transfer data to one-hot representation

# %%
print(questions_with_plus[:5], expected_with_plus[:5])
# Out:
# ['8+36   ', '49+2   ', '9+16   ', '9+918  ', '592+5  '] ['44  ', '51  ', '25  ', '927 ', '597 ']

# %%
questions = questions_with_plus
expected = expected_with_plus

# %% [markdown]
# ## Split data into training, validation, testing

# %%
print('Vectorization...')
x = np.zeros((len(questions), MAXLEN, len(chars)), dtype=np.bool)
y = np.zeros((len(expected), DIGITS + 1, len(chars)), dtype=np.bool)
for i, sentence in enumerate(questions):
    x[i] = ctable.encode(sentence, MAXLEN)
for i, sentence in enumerate(expected):
    y[i] = ctable.encode(sentence, DIGITS + 1)
# Out:
# Vectorization...

# %%
indices = np.arange(len(y))
np.random.shuffle(indices)
x = x[indices]
y = y[indices]

# train_test_split
train_x = x[:20000]
train_y = y[:20000]
test_x = x[20000:]
test_y = y[20000:]


split_at = len(train_x) - len(train_x) // 10
(x_train, x_val) = train_x[:split_at], train_x[split_at:]
(y_train, y_val) = train_y[:split_at], train_y[split_at:]

print('Training Data:')
print(x_train.shape)
print(y_train.shape)

print('Validation Data:')
print(x_val.shape)
print(y_val.shape)

print('Testing Data:')
print(test_x.shape)
print(test_y.shape)
# Out:
# Training Data:
# (18000, 7, 12)
# (18000, 4, 12)
# Validation Data:
# (2000, 7, 12)
# (2000, 4, 12)
# Testing Data:
# (60000, 7, 12)
# (60000, 4, 12)

# %%
# print("input: ", x_train[:3], '\n\n', "label: ", y_train[:3])
# Out:
# input:  [[[False False False False False  True False False False False False
#    False]
#   [False False False False False False False False False  True False
#    False]
#   [False False False False False False False  True False False False
#    False]
#   [False  True False False False False False False False False False
#    False]
#   [False False False False False False False  True False False False
#    False]
#   [False False False False False False  True False False False False
#    False]
#   [ True False False False False False False False False False False
#    False]]
#
#  [[False False False False  True False False False False False False
#    False]
#   [False False False False False  True False False False False False
#    False]
#   [False  True False False False False False False False False False
#    False]
#   [False False False False False False False  True False False False
#    False]
#   [False False False False False False False False False  True False
#    False]
#   [False False False False False  True False False False False False
#    False]
#   [ True False False False False False False False False False False
#    False]]
#
#  [[False False False False False  True False False False False False
#    False]
#   [False False False False False False  True False False False False
#    False]
#   [False False False  True False False False False False False False
#    False]
#   [False  True False False False False False False False False False
#    False]
#   [False False False False False False  True False False False False
#    False]
#   [ True False False False False False False False False False False
#    False]
#   [ True False False False False False False False False False False
#    False]]]
#
#  label:  [[[False False False False False False  True False False False False
#    False]
#   [False False False False  True False False False False False False
#    False]
#   [False False False False False False False False False False False
#     True]
#   [ True False False False False False False False False False False
#    False]]
#
#  [[False False False False False False False  True False False False
#    False]
#   [False False False False False False False False False False False
#     True]
#   [False False False False False False False False  True False False
#    False]
#   [ True False False False False False False False False False False
#    False]]
#
#  [[False False False False False  True False False False False False
#    False]
#   [False False False False False False  True False False False False
#    False]
#   [False False False False False False False  True False False False
#    False]
#   [ True False False False False False False False False False False
#    False]]]

# %% [markdown]
# ## Build Model

# %%
from keras.layers import *

model = Sequential()
model.add(LSTM(HIDDEN_SIZE, input_shape=(MAXLEN, len(chars))))
model.add(layers.RepeatVector(DIGITS + 1))
model.add(LSTM(HIDDEN_SIZE, return_sequences=True))
model.add(layers.TimeDistributed(layers.Dense(len(chars), activation='softmax')))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_8 (LSTM)                (None, 128)               72192
# _________________________________________________________________
# repeat_vector_5 (RepeatVecto (None, 4, 128)            0
# _________________________________________________________________
# lstm_9 (LSTM)                (None, 4, 128)            131584
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 4, 12)             1548
# =================================================================
# Total params: 205,324
# Trainable params: 205,324
# Non-trainable params: 0
# _________________________________________________________________

# %%
trainData = x_train
trainTarget = y_train
testData = test_x
testTarget = test_y

print("~~~")
for iteration in range(100):
    print()
    print('-' * 50)
    print('Iteration', iteration)
    model.fit(trainData, trainTarget,
              epochs=1,
              batch_size=100,
              shuffle=True,
              validation_data=(x_val, y_val),
              verbose =2,
              )
    for i in range(10):
        ind = np.random.randint(0, len(testData))
        rowx, rowy = testData[np.array([ind])], testTarget[np.array([ind])]
        preds = model.predict(rowx)[0]
        q = ctable.decode(rowx[0])
        correct = ctable.decode(rowy[0])
        guess = ctable.decode(preds)
        print('Q', q[::-1] if REVERSE else q, end=' ')
        print('T', correct, end=' ')
        if correct == guess:
            print(colors.ok + '☑' + colors.close, end=' ')
        else:
            print(colors.fail + '☒' + colors.close, end=' ')
        print(guess)
# Out:
# ~~~
#
# --------------------------------------------------
# Iteration 0
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 254s - loss: 1.9902 - acc: 0.2948 - val_loss: 1.8717 - val_acc: 0.3241
# Q 543+19  T 562  ☒ 137
# Q 86+466  T 552  ☒ 107
# Q 99+647  T 746  ☒ 104
# Q 668+182 T 850  ☒ 110
# Q 20+656  T 676  ☒ 137
# Q 875+32  T 907  ☒ 137
# Q 610+528 T 1138 ☒ 100
# Q 6+43    T 49   ☒ 13
# Q 48+7    T 55   ☒ 13
# Q 44+928  T 972  ☒ 137
#
# --------------------------------------------------
# Iteration 1
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 249s - loss: 1.8356 - acc: 0.3310 - val_loss: 1.8139 - val_acc: 0.3329
# Q 937+66  T 1003 ☒ 104
# Q 46+993  T 1039 ☒ 104
# Q 36+639  T 675  ☒ 104
# Q 3+878   T 881  ☒ 444
# Q 665+119 T 784  ☒ 104
# Q 625+28  T 653  ☒ 434
# Q 187+40  T 227  ☒ 104
# Q 27+598  T 625  ☒ 104
# Q 24+185  T 209  ☒ 434
# Q 674+85  T 759  ☒ 104
#
# --------------------------------------------------
# Iteration 2
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 251s - loss: 1.7926 - acc: 0.3375 - val_loss: 1.7730 - val_acc: 0.3515
# Q 62+491  T 553  ☒ 100
# Q 165+880 T 1045 ☒ 100
# Q 509+207 T 716  ☒ 102
# Q 43+460  T 503  ☒ 200
# Q 776+13  T 789  ☒ 800
# Q 828+53  T 881  ☒ 800
# Q 627+868 T 1495 ☒ 1000
# Q 55+472  T 527  ☒ 700
# Q 1+822   T 823  ☒ 22
# Q 389+27  T 416  ☒ 900
#
# --------------------------------------------------
# Iteration 3
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 255s - loss: 1.7310 - acc: 0.3575 - val_loss: 1.7194 - val_acc: 0.3658
# Q 81+69   T 150  ☒ 111
# Q 197+238 T 435  ☒ 341
# Q 468+201 T 669  ☒ 700
# Q 291+396 T 687  ☒ 211
# Q 930+269 T 1199 ☒ 102
# Q 94+409  T 503  ☒ 900
# Q 35+574  T 609  ☒ 400
# Q 483+905 T 1388 ☒ 1321
# Q 356+75  T 431  ☒ 600
# Q 66+62   T 128  ☒ 46
#
# --------------------------------------------------
# Iteration 4
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 252s - loss: 1.6485 - acc: 0.3829 - val_loss: 1.6253 - val_acc: 0.3865
# Q 259+764 T 1023 ☒ 100
# Q 680+40  T 720  ☒ 711
# Q 51+905  T 956  ☒ 902
# Q 53+805  T 858  ☒ 802
# Q 683+930 T 1613 ☒ 1444
# Q 70+981  T 1051 ☒ 104
# Q 118+71  T 189  ☒ 209
# Q 7+86    T 93   ☒ 88
# Q 523+53  T 576  ☒ 601
# Q 498+950 T 1448 ☒ 1121
#
# --------------------------------------------------
# Iteration 5
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 257s - loss: 1.5759 - acc: 0.4074 - val_loss: 1.5522 - val_acc: 0.4135
# Q 816+36  T 852  ☒ 822
# Q 154+1   T 155  ☒ 22
# Q 697+57  T 754  ☒ 722
# Q 907+850 T 1757 ☒ 1444
# Q 187+940 T 1127 ☒ 1022
# Q 54+558  T 612  ☒ 622
# Q 547+308 T 855  ☒ 707
# Q 221+607 T 828  ☒ 802
# Q 45+439  T 484  ☒ 442
# Q 292+893 T 1185 ☒ 1122
#
# --------------------------------------------------
# Iteration 6
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 260s - loss: 1.5032 - acc: 0.4369 - val_loss: 1.4936 - val_acc: 0.4306
# Q 375+56  T 431  ☒ 572
# Q 112+86  T 198  ☒ 202
# Q 300+2   T 302  ☒ 33
# Q 884+97  T 981  ☒ 905
# Q 224+99  T 323  ☒ 301
# Q 517+96  T 613  ☒ 651
# Q 520+629 T 1149 ☒ 1259
# Q 703+30  T 733  ☒ 778
# Q 821+764 T 1585 ☒ 1621
# Q 976+21  T 997  ☒ 901
#
# --------------------------------------------------
# Iteration 7
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 289s - loss: 1.4414 - acc: 0.4601 - val_loss: 1.4322 - val_acc: 0.4555
# Q 472+92  T 564  ☒ 499
# Q 955+68  T 1023 ☒ 1021
# Q 915+54  T 969  ☒ 900
# Q 386+342 T 728  ☒ 776
# Q 609+20  T 629  ☒ 695
# Q 57+62   T 119  ☒ 666
# Q 591+191 T 782  ☒ 605
# Q 86+759  T 845  ☒ 766
# Q 75+371  T 446  ☒ 471
# Q 209+31  T 240  ☒ 399
#
# --------------------------------------------------
# Iteration 8
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 272s - loss: 1.3915 - acc: 0.4782 - val_loss: 1.4045 - val_acc: 0.4621
# Q 585+37  T 622  ☒ 629
# Q 41+722  T 763  ☒ 865
# Q 516+83  T 599  ☒ 699
# Q 805+98  T 903  ☒ 979
# Q 7+892   T 899  ☒ 987
# Q 214+572 T 786  ☒ 889
# Q 28+729  T 757  ☒ 765
# Q 598+48  T 646  ☒ 565
# Q 48+10   T 58   ☒ 11
# Q 131+20  T 151  ☒ 144
#
# --------------------------------------------------
# Iteration 9
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 268s - loss: 1.3345 - acc: 0.5015 - val_loss: 1.3374 - val_acc: 0.4931
# Q 701+87  T 788  ☒ 887
# Q 25+73   T 98   ☒ 11
# Q 922+33  T 955  ☒ 966
# Q 522+629 T 1151 ☒ 1166
# Q 7+334   T 341  ☑ 341
# Q 65+810  T 875  ☒ 877
# Q 17+394  T 411  ☑ 411
# Q 428+702 T 1130 ☒ 1196
# Q 719+525 T 1244 ☒ 1166
# Q 272+626 T 898  ☒ 901
#
# --------------------------------------------------
# Iteration 10
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 276s - loss: 1.2861 - acc: 0.5210 - val_loss: 1.2937 - val_acc: 0.5151
# Q 276+401 T 677  ☒ 638
# Q 451+643 T 1094 ☒ 1182
# Q 784+71  T 855  ☒ 828
# Q 66+188  T 254  ☒ 255
# Q 1+427   T 428  ☒ 115
# Q 111+95  T 206  ☒ 105
# Q 26+23   T 49   ☒ 55
# Q 30+836  T 866  ☒ 855
# Q 478+858 T 1336 ☒ 1354
# Q 857+65  T 922  ☒ 931
#
# --------------------------------------------------
# Iteration 11
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 253s - loss: 1.2428 - acc: 0.5390 - val_loss: 1.2823 - val_acc: 0.5105
# Q 562+65  T 627  ☒ 620
# Q 172+93  T 265  ☒ 295
# Q 938+950 T 1888 ☒ 1844
# Q 431+9   T 440  ☒ 443
# Q 813+185 T 998  ☒ 902
# Q 90+416  T 506  ☒ 535
# Q 47+776  T 823  ☒ 831
# Q 914+285 T 1199 ☒ 1264
# Q 5+458   T 463  ☒ 554
# Q 11+475  T 486  ☒ 475
#
# --------------------------------------------------
# Iteration 12
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 277s - loss: 1.2021 - acc: 0.5513 - val_loss: 1.2209 - val_acc: 0.5394
# Q 796+5   T 801  ☒ 163
# Q 800+0   T 800  ☒ 810
# Q 82+55   T 137  ☒ 149
# Q 954+40  T 994  ☒ 996
# Q 373+617 T 990  ☒ 901
# Q 126+65  T 191  ☒ 189
# Q 408+522 T 930  ☒ 952
# Q 78+260  T 338  ☒ 335
# Q 856+181 T 1037 ☒ 900
# Q 350+76  T 426  ☒ 431
#
# --------------------------------------------------
# Iteration 13
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 264s - loss: 1.1610 - acc: 0.5686 - val_loss: 1.1879 - val_acc: 0.5567
# Q 67+99   T 166  ☒ 105
# Q 273+990 T 1263 ☒ 1219
# Q 72+649  T 721  ☒ 725
# Q 310+80  T 390  ☒ 311
# Q 835+47  T 882  ☒ 888
# Q 293+378 T 671  ☒ 757
# Q 50+211  T 261  ☒ 242
# Q 972+849 T 1821 ☒ 1872
# Q 498+80  T 578  ☒ 587
# Q 190+635 T 825  ☒ 877
#
# --------------------------------------------------
# Iteration 14
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 313s - loss: 1.1233 - acc: 0.5817 - val_loss: 1.1465 - val_acc: 0.5649
# Q 608+77  T 685  ☒ 677
# Q 38+81   T 119  ☒ 114
# Q 528+40  T 568  ☒ 541
# Q 75+998  T 1073 ☒ 1063
# Q 147+168 T 315  ☒ 207
# Q 347+78  T 425  ☒ 442
# Q 760+71  T 831  ☒ 854
# Q 270+6   T 276  ☒ 277
# Q 124+127 T 251  ☒ 254
# Q 805+437 T 1242 ☒ 1222
#
# --------------------------------------------------
# Iteration 15
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 310s - loss: 1.0736 - acc: 0.5997 - val_loss: 1.1013 - val_acc: 0.5816
# Q 247+63  T 310  ☒ 391
# Q 511+45  T 556  ☒ 565
# Q 482+651 T 1133 ☒ 1159
# Q 701+1   T 702  ☒ 802
# Q 6+564   T 570  ☒ 561
# Q 613+57  T 670  ☒ 685
# Q 70+181  T 251  ☒ 265
# Q 178+12  T 190  ☒ 109
# Q 212+0   T 212  ☒ 211
# Q 54+330  T 384  ☒ 379
#
# --------------------------------------------------
# Iteration 16
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 303s - loss: 1.0361 - acc: 0.6147 - val_loss: 1.0540 - val_acc: 0.5984
# Q 45+603  T 648  ☒ 655
# Q 4+82    T 86   ☒ 94
# Q 32+720  T 752  ☒ 741
# Q 986+403 T 1389 ☒ 1365
# Q 175+242 T 417  ☒ 421
# Q 321+791 T 1112 ☒ 1115
# Q 274+429 T 703  ☒ 748
# Q 353+283 T 636  ☒ 618
# Q 371+217 T 588  ☒ 698
# Q 723+4   T 727  ☒ 726
#
# --------------------------------------------------
# Iteration 17
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 243s - loss: 0.9919 - acc: 0.6339 - val_loss: 1.0119 - val_acc: 0.6144
# Q 411+860 T 1271 ☒ 1212
# Q 5+333   T 338  ☒ 330
# Q 30+560  T 590  ☒ 605
# Q 370+69  T 439  ☒ 457
# Q 331+531 T 862  ☒ 765
# Q 676+809 T 1485 ☒ 1476
# Q 37+938  T 975  ☒ 992
# Q 464+539 T 1003 ☒ 1011
# Q 206+90  T 296  ☒ 209
# Q 405+9   T 414  ☒ 433
#
# --------------------------------------------------
# Iteration 18
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 70s - loss: 0.9524 - acc: 0.6470 - val_loss: 0.9769 - val_acc: 0.6286
# Q 302+843 T 1145 ☒ 1056
# Q 85+994  T 1079 ☒ 1073
# Q 67+219  T 286  ☒ 282
# Q 320+818 T 1138 ☑ 1138
# Q 732+581 T 1313 ☒ 1382
# Q 968+30  T 998  ☒ 990
# Q 39+275  T 314  ☒ 324
# Q 404+584 T 988  ☑ 988
# Q 0+648   T 648  ☒ 646
# Q 589+878 T 1467 ☒ 1474
#
# --------------------------------------------------
# Iteration 19
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 86s - loss: 0.9037 - acc: 0.6670 - val_loss: 0.9339 - val_acc: 0.6349
# Q 395+94  T 489  ☒ 481
# Q 72+772  T 844  ☒ 833
# Q 3+502   T 505  ☒ 513
# Q 6+277   T 283  ☒ 273
# Q 966+42  T 1008 ☑ 1008
# Q 62+549  T 611  ☒ 605
# Q 62+93   T 155  ☒ 143
# Q 128+13  T 141  ☒ 147
# Q 145+59  T 204  ☒ 213
# Q 8+570   T 578  ☒ 577
#
# --------------------------------------------------
# Iteration 20
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 77s - loss: 0.8516 - acc: 0.6840 - val_loss: 0.8770 - val_acc: 0.6615
# Q 156+69  T 225  ☒ 224
# Q 485+796 T 1281 ☒ 1264
# Q 415+98  T 513  ☒ 521
# Q 320+35  T 355  ☒ 358
# Q 753+697 T 1450 ☒ 1440
# Q 77+208  T 285  ☒ 296
# Q 253+805 T 1058 ☒ 1055
# Q 46+755  T 801  ☒ 800
# Q 545+666 T 1211 ☒ 1201
# Q 939+72  T 1011 ☑ 1011
#
# --------------------------------------------------
# Iteration 21
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 94s - loss: 0.7844 - acc: 0.7109 - val_loss: 0.7907 - val_acc: 0.6953
# Q 950+839 T 1789 ☒ 1704
# Q 147+34  T 181  ☒ 171
# Q 134+97  T 231  ☒ 221
# Q 141+894 T 1035 ☒ 1039
# Q 567+78  T 645  ☒ 643
# Q 4+927   T 931  ☒ 943
# Q 3+146   T 149  ☒ 148
# Q 10+156  T 166  ☒ 178
# Q 3+663   T 666  ☑ 666
# Q 777+189 T 966  ☑ 966
#
# --------------------------------------------------
# Iteration 22
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 97s - loss: 0.7086 - acc: 0.7393 - val_loss: 0.7125 - val_acc: 0.7278
# Q 624+631 T 1255 ☑ 1255
# Q 73+132  T 205  ☑ 205
# Q 211+715 T 926  ☒ 924
# Q 253+5   T 258  ☑ 258
# Q 13+319  T 332  ☒ 331
# Q 28+605  T 633  ☒ 631
# Q 23+542  T 565  ☑ 565
# Q 890+712 T 1602 ☒ 1510
# Q 18+674  T 692  ☒ 691
# Q 657+255 T 912  ☒ 921
#
# --------------------------------------------------
# Iteration 23
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 82s - loss: 0.6208 - acc: 0.7800 - val_loss: 0.6261 - val_acc: 0.7664
# Q 647+88  T 735  ☒ 734
# Q 302+20  T 322  ☒ 311
# Q 360+30  T 390  ☒ 401
# Q 445+10  T 455  ☑ 455
# Q 53+819  T 872  ☒ 871
# Q 45+945  T 990  ☒ 989
# Q 622+80  T 702  ☑ 702
# Q 13+215  T 228  ☒ 240
# Q 11+207  T 218  ☒ 228
# Q 648+702 T 1350 ☒ 1359
#
# --------------------------------------------------
# Iteration 24
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 82s - loss: 0.5457 - acc: 0.8124 - val_loss: 0.5540 - val_acc: 0.7979
# Q 266+66  T 332  ☑ 332
# Q 594+903 T 1497 ☒ 1404
# Q 52+780  T 832  ☑ 832
# Q 83+931  T 1014 ☑ 1014
# Q 258+947 T 1205 ☒ 1106
# Q 67+357  T 424  ☑ 424
# Q 53+540  T 593  ☒ 693
# Q 736+568 T 1304 ☑ 1304
# Q 5+388   T 393  ☒ 383
# Q 46+337  T 383  ☑ 383
#
# --------------------------------------------------
# Iteration 25
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 78s - loss: 0.4813 - acc: 0.8430 - val_loss: 0.5034 - val_acc: 0.8169
# Q 132+28  T 160  ☒ 161
# Q 89+781  T 870  ☑ 870
# Q 52+844  T 896  ☒ 897
# Q 1+66    T 67   ☑ 67
# Q 873+23  T 896  ☒ 897
# Q 31+656  T 687  ☑ 687
# Q 692+73  T 765  ☑ 765
# Q 5+236   T 241  ☒ 231
# Q 772+782 T 1554 ☑ 1554
# Q 319+619 T 938  ☒ 937
#
# --------------------------------------------------
# Iteration 26
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 71s - loss: 0.4253 - acc: 0.8704 - val_loss: 0.4397 - val_acc: 0.8603
# Q 74+412  T 486  ☑ 486
# Q 83+648  T 731  ☑ 731
# Q 472+50  T 522  ☑ 522
# Q 71+82   T 153  ☑ 153
# Q 261+44  T 305  ☑ 305
# Q 23+856  T 879  ☑ 879
# Q 77+76   T 153  ☑ 153
# Q 114+5   T 119  ☑ 119
# Q 428+844 T 1272 ☑ 1272
# Q 32+320  T 352  ☒ 353
#
# --------------------------------------------------
# Iteration 27
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 72s - loss: 0.3742 - acc: 0.8965 - val_loss: 0.4097 - val_acc: 0.8656
# Q 991+252 T 1243 ☑ 1243
# Q 11+45   T 56   ☑ 56
# Q 690+75  T 765  ☑ 765
# Q 10+977  T 987  ☑ 987
# Q 46+929  T 975  ☒ 976
# Q 977+477 T 1454 ☑ 1454
# Q 409+91  T 500  ☑ 500
# Q 833+445 T 1278 ☒ 1288
# Q 108+587 T 695  ☒ 705
# Q 75+14   T 89   ☒ 99
#
# --------------------------------------------------
# Iteration 28
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 106s - loss: 0.3377 - acc: 0.9108 - val_loss: 0.3688 - val_acc: 0.8844
# Q 839+3   T 842  ☑ 842
# Q 180+473 T 653  ☒ 644
# Q 313+36  T 349  ☑ 349
# Q 78+674  T 752  ☑ 752
# Q 904+210 T 1114 ☑ 1114
# Q 884+0   T 884  ☑ 884
# Q 36+627  T 663  ☑ 663
# Q 295+81  T 376  ☒ 377
# Q 877+758 T 1635 ☒ 1634
# Q 704+221 T 925  ☒ 935
#
# --------------------------------------------------
# Iteration 29
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 99s - loss: 0.3087 - acc: 0.9196 - val_loss: 0.3297 - val_acc: 0.9061
# Q 264+13  T 277  ☒ 287
# Q 658+11  T 669  ☒ 679
# Q 639+148 T 787  ☑ 787
# Q 784+49  T 833  ☑ 833
# Q 277+691 T 968  ☑ 968
# Q 513+26  T 539  ☒ 549
# Q 438+529 T 967  ☑ 967
# Q 427+632 T 1059 ☒ 1060
# Q 474+90  T 564  ☒ 554
# Q 975+467 T 1442 ☑ 1442
#
# --------------------------------------------------
# Iteration 30
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 93s - loss: 0.2843 - acc: 0.9263 - val_loss: 0.3206 - val_acc: 0.9045
# Q 720+53  T 773  ☑ 773
# Q 50+559  T 609  ☑ 609
# Q 64+468  T 532  ☑ 532
# Q 323+631 T 954  ☑ 954
# Q 313+77  T 390  ☑ 390
# Q 973+281 T 1254 ☒ 1243
# Q 445+678 T 1123 ☒ 1133
# Q 775+875 T 1650 ☑ 1650
# Q 266+283 T 549  ☑ 549
# Q 3+606   T 609  ☒ 619
#
# --------------------------------------------------
# Iteration 31
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 85s - loss: 0.2533 - acc: 0.9397 - val_loss: 0.3033 - val_acc: 0.9110
# Q 654+50  T 704  ☑ 704
# Q 857+98  T 955  ☑ 955
# Q 36+474  T 510  ☑ 510
# Q 282+19  T 301  ☒ 201
# Q 1+758   T 759  ☑ 759
# Q 84+240  T 324  ☑ 324
# Q 635+807 T 1442 ☒ 1443
# Q 10+27   T 37   ☑ 37
# Q 30+290  T 320  ☑ 320
# Q 962+38  T 1000 ☑ 1000
#
# --------------------------------------------------
# Iteration 32
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 99s - loss: 0.2233 - acc: 0.9512 - val_loss: 0.2500 - val_acc: 0.9304
# Q 28+96   T 124  ☑ 124
# Q 257+9   T 266  ☑ 266
# Q 407+710 T 1117 ☑ 1117
# Q 35+356  T 391  ☑ 391
# Q 267+572 T 839  ☑ 839
# Q 245+473 T 718  ☑ 718
# Q 875+375 T 1250 ☑ 1250
# Q 543+836 T 1379 ☑ 1379
# Q 118+392 T 510  ☒ 519
# Q 26+178  T 204  ☑ 204
#
# --------------------------------------------------
# Iteration 33
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 126s - loss: 0.2046 - acc: 0.9572 - val_loss: 0.2286 - val_acc: 0.9399
# Q 748+524 T 1272 ☑ 1272
# Q 999+1   T 1000 ☒ 199
# Q 32+325  T 357  ☑ 357
# Q 162+173 T 335  ☑ 335
# Q 853+670 T 1523 ☑ 1523
# Q 957+34  T 991  ☑ 991
# Q 83+310  T 393  ☑ 393
# Q 94+111  T 205  ☑ 205
# Q 47+859  T 906  ☒ 806
# Q 9+575   T 584  ☑ 584
#
# --------------------------------------------------
# Iteration 34
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 148s - loss: 0.1808 - acc: 0.9643 - val_loss: 0.3635 - val_acc: 0.8790
# Q 705+704 T 1409 ☒ 1319
# Q 253+46  T 299  ☑ 299
# Q 1+930   T 931  ☒ 922
# Q 54+810  T 864  ☑ 864
# Q 909+973 T 1882 ☒ 1872
# Q 19+360  T 379  ☑ 379
# Q 71+343  T 414  ☑ 414
# Q 374+290 T 664  ☑ 664
# Q 924+56  T 980  ☒ 970
# Q 110+592 T 702  ☒ 692
#
# --------------------------------------------------
# Iteration 35
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 149s - loss: 0.1887 - acc: 0.9560 - val_loss: 0.2064 - val_acc: 0.9427
# Q 979+883 T 1862 ☑ 1862
# Q 2+903   T 905  ☑ 905
# Q 735+77  T 812  ☑ 812
# Q 937+51  T 988  ☑ 988
# Q 98+850  T 948  ☑ 948
# Q 96+94   T 190  ☑ 190
# Q 117+12  T 129  ☑ 129
# Q 45+152  T 197  ☑ 197
# Q 19+1    T 20   ☒ 19
# Q 44+830  T 874  ☑ 874
#
# --------------------------------------------------
# Iteration 36
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 208s - loss: 0.1508 - acc: 0.9719 - val_loss: 0.1944 - val_acc: 0.9464
# Q 387+238 T 625  ☑ 625
# Q 558+5   T 563  ☑ 563
# Q 777+407 T 1184 ☑ 1184
# Q 191+3   T 194  ☑ 194
# Q 39+33   T 72   ☑ 72
# Q 665+285 T 950  ☑ 950
# Q 894+44  T 938  ☒ 939
# Q 816+36  T 852  ☑ 852
# Q 77+28   T 105  ☑ 105
# Q 59+0    T 59   ☑ 59
#
# --------------------------------------------------
# Iteration 37
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 108s - loss: 0.1410 - acc: 0.9726 - val_loss: 0.2003 - val_acc: 0.9356
# Q 467+271 T 738  ☑ 738
# Q 40+705  T 745  ☑ 745
# Q 436+14  T 450  ☒ 440
# Q 320+7   T 327  ☑ 327
# Q 701+1   T 702  ☑ 702
# Q 82+675  T 757  ☑ 757
# Q 33+302  T 335  ☑ 335
# Q 109+636 T 745  ☑ 745
# Q 65+860  T 925  ☑ 925
# Q 546+33  T 579  ☑ 579
#
# --------------------------------------------------
# Iteration 38
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 121s - loss: 0.1587 - acc: 0.9636 - val_loss: 0.1640 - val_acc: 0.9554
# Q 561+25  T 586  ☑ 586
# Q 371+97  T 468  ☒ 478
# Q 120+28  T 148  ☑ 148
# Q 19+19   T 38   ☒ 57
# Q 20+410  T 430  ☑ 430
# Q 88+665  T 753  ☑ 753
# Q 392+6   T 398  ☑ 398
# Q 382+172 T 554  ☑ 554
# Q 98+142  T 240  ☑ 240
# Q 714+121 T 835  ☑ 835
#
# --------------------------------------------------
# Iteration 39
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 101s - loss: 0.1135 - acc: 0.9813 - val_loss: 0.1514 - val_acc: 0.9606
# Q 67+324  T 391  ☑ 391
# Q 395+51  T 446  ☑ 446
# Q 6+563   T 569  ☑ 569
# Q 425+66  T 491  ☑ 491
# Q 869+21  T 890  ☒ 880
# Q 583+0   T 583  ☑ 583
# Q 872+957 T 1829 ☑ 1829
# Q 38+337  T 375  ☑ 375
# Q 893+786 T 1679 ☑ 1679
# Q 48+82   T 130  ☒ 120
#
# --------------------------------------------------
# Iteration 40
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 93s - loss: 0.1014 - acc: 0.9849 - val_loss: 0.1444 - val_acc: 0.9612
# Q 485+5   T 490  ☑ 490
# Q 392+26  T 418  ☑ 418
# Q 99+533  T 632  ☑ 632
# Q 534+709 T 1243 ☑ 1243
# Q 461+87  T 548  ☑ 548
# Q 623+948 T 1571 ☑ 1571
# Q 153+91  T 244  ☑ 244
# Q 578+8   T 586  ☑ 586
# Q 816+10  T 826  ☑ 826
# Q 97+375  T 472  ☑ 472
#
# --------------------------------------------------
# Iteration 41
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 76s - loss: 0.1189 - acc: 0.9739 - val_loss: 0.1869 - val_acc: 0.9360
# Q 940+87  T 1027 ☑ 1027
# Q 634+569 T 1203 ☑ 1203
# Q 54+170  T 224  ☑ 224
# Q 49+879  T 928  ☑ 928
# Q 47+699  T 746  ☑ 746
# Q 27+820  T 847  ☑ 847
# Q 514+209 T 723  ☒ 733
# Q 157+8   T 165  ☑ 165
# Q 234+59  T 293  ☑ 293
# Q 22+362  T 384  ☑ 384
#
# --------------------------------------------------
# Iteration 42
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 94s - loss: 0.0991 - acc: 0.9811 - val_loss: 0.1292 - val_acc: 0.9640
# Q 57+355  T 412  ☑ 412
# Q 808+54  T 862  ☑ 862
# Q 748+626 T 1374 ☑ 1374
# Q 76+298  T 374  ☑ 374
# Q 53+224  T 277  ☑ 277
# Q 196+0   T 196  ☑ 196
# Q 650+42  T 692  ☑ 692
# Q 76+790  T 866  ☑ 866
# Q 250+39  T 289  ☑ 289
# Q 9+127   T 136  ☑ 136
#
# --------------------------------------------------
# Iteration 43
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 90s - loss: 0.0836 - acc: 0.9861 - val_loss: 0.1371 - val_acc: 0.9601
# Q 733+62  T 795  ☑ 795
# Q 7+189   T 196  ☑ 196
# Q 76+498  T 574  ☑ 574
# Q 39+949  T 988  ☒ 987
# Q 84+458  T 542  ☑ 542
# Q 871+404 T 1275 ☑ 1275
# Q 379+3   T 382  ☑ 382
# Q 992+608 T 1600 ☒ 1590
# Q 566+519 T 1085 ☑ 1085
# Q 530+621 T 1151 ☑ 1151
#
# --------------------------------------------------
# Iteration 44
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 92s - loss: 0.0966 - acc: 0.9788 - val_loss: 0.1190 - val_acc: 0.9648
# Q 487+241 T 728  ☑ 728
# Q 106+706 T 812  ☒ 822
# Q 668+88  T 756  ☑ 756
# Q 542+76  T 618  ☑ 618
# Q 422+23  T 445  ☑ 445
# Q 853+13  T 866  ☒ 867
# Q 649+908 T 1557 ☑ 1557
# Q 22+90   T 112  ☑ 112
# Q 739+58  T 797  ☑ 797
# Q 196+1   T 197  ☑ 197
#
# --------------------------------------------------
# Iteration 45
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 110s - loss: 0.0713 - acc: 0.9883 - val_loss: 0.1116 - val_acc: 0.9672
# Q 202+1   T 203  ☒ 103
# Q 63+601  T 664  ☑ 664
# Q 44+373  T 417  ☑ 417
# Q 712+300 T 1012 ☒ 1010
# Q 94+24   T 118  ☑ 118
# Q 48+471  T 519  ☑ 519
# Q 329+62  T 391  ☑ 391
# Q 835+74  T 909  ☑ 909
# Q 226+17  T 243  ☑ 243
# Q 92+902  T 994  ☑ 994
#
# --------------------------------------------------
# Iteration 46
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 49s - loss: 0.0620 - acc: 0.9918 - val_loss: 0.1141 - val_acc: 0.9688
# Q 89+366  T 455  ☑ 455
# Q 595+687 T 1282 ☑ 1282
# Q 400+413 T 813  ☑ 813
# Q 87+351  T 438  ☑ 438
# Q 6+893   T 899  ☒ 909
# Q 86+538  T 624  ☑ 624
# Q 635+3   T 638  ☑ 638
# Q 50+561  T 611  ☑ 611
# Q 522+540 T 1062 ☑ 1062
# Q 95+770  T 865  ☑ 865
#
# --------------------------------------------------
# Iteration 47
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 56s - loss: 0.0684 - acc: 0.9885 - val_loss: 0.1241 - val_acc: 0.9631
# Q 536+577 T 1113 ☑ 1113
# Q 910+959 T 1869 ☒ 1879
# Q 381+319 T 700  ☒ 790
# Q 234+54  T 288  ☑ 288
# Q 81+949  T 1030 ☑ 1030
# Q 8+498   T 506  ☑ 506
# Q 750+31  T 781  ☑ 781
# Q 327+861 T 1188 ☑ 1188
# Q 197+45  T 242  ☑ 242
# Q 914+227 T 1141 ☑ 1141
#
# --------------------------------------------------
# Iteration 48
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 90s - loss: 0.1050 - acc: 0.9707 - val_loss: 0.0949 - val_acc: 0.9743
# Q 300+971 T 1271 ☑ 1271
# Q 360+55  T 415  ☑ 415
# Q 732+581 T 1313 ☑ 1313
# Q 449+44  T 493  ☑ 493
# Q 109+51  T 160  ☒ 150
# Q 707+563 T 1270 ☑ 1270
# Q 9+61    T 70   ☒ 60
# Q 114+6   T 120  ☑ 120
# Q 34+407  T 441  ☒ 431
# Q 647+88  T 735  ☑ 735
#
# --------------------------------------------------
# Iteration 49
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 69s - loss: 0.0512 - acc: 0.9928 - val_loss: 0.0894 - val_acc: 0.9745
# Q 372+45  T 417  ☑ 417
# Q 59+344  T 403  ☑ 403
# Q 128+36  T 164  ☑ 164
# Q 563+49  T 612  ☑ 612
# Q 890+238 T 1128 ☑ 1128
# Q 9+575   T 584  ☑ 584
# Q 120+67  T 187  ☑ 187
# Q 912+29  T 941  ☑ 941
# Q 364+886 T 1250 ☑ 1250
# Q 387+14  T 401  ☑ 401
#
# --------------------------------------------------
# Iteration 50
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 68s - loss: 0.0617 - acc: 0.9883 - val_loss: 0.1044 - val_acc: 0.9677
# Q 28+636  T 664  ☑ 664
# Q 867+81  T 948  ☑ 948
# Q 740+990 T 1730 ☑ 1730
# Q 16+414  T 430  ☑ 430
# Q 48+851  T 899  ☒ 999
# Q 51+397  T 448  ☑ 448
# Q 16+479  T 495  ☑ 495
# Q 14+841  T 855  ☑ 855
# Q 87+755  T 842  ☑ 842
# Q 684+4   T 688  ☑ 688
#
# --------------------------------------------------
# Iteration 51
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 78s - loss: 0.0474 - acc: 0.9927 - val_loss: 0.0957 - val_acc: 0.9686
# Q 511+38  T 549  ☑ 549
# Q 37+340  T 377  ☑ 377
# Q 755+96  T 851  ☑ 851
# Q 244+10  T 254  ☒ 244
# Q 932+12  T 944  ☑ 944
# Q 999+137 T 1136 ☑ 1136
# Q 352+8   T 360  ☒ 350
# Q 20+102  T 122  ☒ 121
# Q 153+928 T 1081 ☑ 1081
# Q 481+552 T 1033 ☑ 1033
#
# --------------------------------------------------
# Iteration 52
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 88s - loss: 0.0407 - acc: 0.9948 - val_loss: 0.0839 - val_acc: 0.9751
# Q 856+931 T 1787 ☑ 1787
# Q 89+543  T 632  ☑ 632
# Q 59+682  T 741  ☑ 741
# Q 808+26  T 834  ☑ 834
# Q 800+40  T 840  ☑ 840
# Q 81+544  T 625  ☑ 625
# Q 960+57  T 1017 ☒ 1007
# Q 91+500  T 591  ☑ 591
# Q 816+11  T 827  ☑ 827
# Q 415+217 T 632  ☑ 632
#
# --------------------------------------------------
# Iteration 53
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 90s - loss: 0.0382 - acc: 0.9947 - val_loss: 0.0800 - val_acc: 0.9749
# Q 780+423 T 1203 ☑ 1203
# Q 87+703  T 790  ☑ 790
# Q 62+564  T 626  ☑ 626
# Q 769+100 T 869  ☒ 879
# Q 99+61   T 160  ☑ 160
# Q 0+990   T 990  ☒ 991
# Q 95+404  T 499  ☒ 599
# Q 842+703 T 1545 ☑ 1545
# Q 275+233 T 508  ☑ 508
# Q 460+7   T 467  ☑ 467
#
# --------------------------------------------------
# Iteration 54
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 105s - loss: 0.0646 - acc: 0.9836 - val_loss: 0.1866 - val_acc: 0.9310
# Q 26+56   T 82   ☒ 83
# Q 708+8   T 716  ☑ 716
# Q 7+622   T 629  ☑ 629
# Q 57+57   T 114  ☑ 114
# Q 85+200  T 285  ☑ 285
# Q 30+804  T 834  ☑ 834
# Q 17+946  T 963  ☑ 963
# Q 808+54  T 862  ☑ 862
# Q 3+341   T 344  ☑ 344
# Q 0+194   T 194  ☑ 194
#
# --------------------------------------------------
# Iteration 55
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 95s - loss: 0.0598 - acc: 0.9858 - val_loss: 0.0799 - val_acc: 0.9769
# Q 824+32  T 856  ☑ 856
# Q 332+58  T 390  ☑ 390
# Q 493+3   T 496  ☑ 496
# Q 96+873  T 969  ☒ 979
# Q 632+43  T 675  ☑ 675
# Q 937+78  T 1015 ☑ 1015
# Q 68+110  T 178  ☑ 178
# Q 342+172 T 514  ☑ 514
# Q 292+97  T 389  ☑ 389
# Q 665+276 T 941  ☑ 941
#
# --------------------------------------------------
# Iteration 56
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 124s - loss: 0.0306 - acc: 0.9966 - val_loss: 0.0720 - val_acc: 0.9781
# Q 75+723  T 798  ☑ 798
# Q 849+202 T 1051 ☑ 1051
# Q 370+13  T 383  ☑ 383
# Q 472+4   T 476  ☑ 476
# Q 86+695  T 781  ☑ 781
# Q 34+438  T 472  ☑ 472
# Q 32+914  T 946  ☑ 946
# Q 809+33  T 842  ☑ 842
# Q 64+614  T 678  ☑ 678
# Q 436+5   T 441  ☑ 441
#
# --------------------------------------------------
# Iteration 57
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 104s - loss: 0.0353 - acc: 0.9945 - val_loss: 0.0740 - val_acc: 0.9775
# Q 2+716   T 718  ☑ 718
# Q 943+97  T 1040 ☑ 1040
# Q 101+16  T 117  ☒ 127
# Q 516+321 T 837  ☑ 837
# Q 24+742  T 766  ☑ 766
# Q 49+632  T 681  ☑ 681
# Q 521+763 T 1284 ☑ 1284
# Q 110+597 T 707  ☑ 707
# Q 284+449 T 733  ☑ 733
# Q 6+320   T 326  ☑ 326
#
# --------------------------------------------------
# Iteration 58
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 109s - loss: 0.0283 - acc: 0.9966 - val_loss: 0.0689 - val_acc: 0.9785
# Q 438+41  T 479  ☑ 479
# Q 66+571  T 637  ☑ 637
# Q 97+9    T 106  ☒ 10
# Q 33+98   T 131  ☑ 131
# Q 961+1   T 962  ☑ 962
# Q 327+35  T 362  ☑ 362
# Q 566+907 T 1473 ☑ 1473
# Q 812+98  T 910  ☒ 900
# Q 251+75  T 326  ☑ 326
# Q 86+780  T 866  ☑ 866
#
# --------------------------------------------------
# Iteration 59
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 137s - loss: 0.0264 - acc: 0.9973 - val_loss: 0.0783 - val_acc: 0.9751
# Q 22+263  T 285  ☑ 285
# Q 854+5   T 859  ☑ 859
# Q 87+733  T 820  ☑ 820
# Q 832+4   T 836  ☑ 836
# Q 583+391 T 974  ☒ 984
# Q 939+125 T 1064 ☒ 1074
# Q 3+155   T 158  ☑ 158
# Q 68+883  T 951  ☑ 951
# Q 793+872 T 1665 ☑ 1665
# Q 89+863  T 952  ☒ 951
#
# --------------------------------------------------
# Iteration 60
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 133s - loss: 0.1253 - acc: 0.9602 - val_loss: 0.0782 - val_acc: 0.9743
# Q 834+2   T 836  ☑ 836
# Q 711+339 T 1050 ☒ 1040
# Q 86+299  T 385  ☑ 385
# Q 75+862  T 937  ☑ 937
# Q 891+81  T 972  ☑ 972
# Q 56+489  T 545  ☑ 545
# Q 89+949  T 1038 ☑ 1038
# Q 112+93  T 205  ☑ 205
# Q 82+947  T 1029 ☑ 1029
# Q 56+232  T 288  ☑ 288
#
# --------------------------------------------------
# Iteration 61
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 118s - loss: 0.0254 - acc: 0.9974 - val_loss: 0.0592 - val_acc: 0.9821
# Q 599+439 T 1038 ☒ 1048
# Q 574+26  T 600  ☒ 500
# Q 11+51   T 62   ☑ 62
# Q 683+930 T 1613 ☑ 1613
# Q 69+676  T 745  ☑ 745
# Q 20+363  T 383  ☑ 383
# Q 10+683  T 693  ☑ 693
# Q 29+705  T 734  ☑ 734
# Q 951+31  T 982  ☑ 982
# Q 867+806 T 1673 ☑ 1673
#
# --------------------------------------------------
# Iteration 62
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 99s - loss: 0.0207 - acc: 0.9982 - val_loss: 0.0578 - val_acc: 0.9828
# Q 87+931  T 1018 ☑ 1018
# Q 605+366 T 971  ☑ 971
# Q 86+76   T 162  ☑ 162
# Q 84+305  T 389  ☑ 389
# Q 637+35  T 672  ☑ 672
# Q 0+840   T 840  ☑ 840
# Q 448+651 T 1099 ☑ 1099
# Q 44+34   T 78   ☑ 78
# Q 19+589  T 608  ☑ 608
# Q 955+15  T 970  ☑ 970
#
# --------------------------------------------------
# Iteration 63
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 105s - loss: 0.0202 - acc: 0.9979 - val_loss: 0.1073 - val_acc: 0.9656
# Q 151+419 T 570  ☑ 570
# Q 55+121  T 176  ☑ 176
# Q 268+475 T 743  ☑ 743
# Q 287+300 T 587  ☒ 588
# Q 74+529  T 603  ☑ 603
# Q 602+48  T 650  ☑ 650
# Q 396+0   T 396  ☑ 396
# Q 83+25   T 108  ☑ 108
# Q 117+371 T 488  ☑ 488
# Q 493+5   T 498  ☑ 498
#
# --------------------------------------------------
# Iteration 64
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 102s - loss: 0.0226 - acc: 0.9966 - val_loss: 0.0635 - val_acc: 0.9801
# Q 43+823  T 866  ☑ 866
# Q 206+3   T 209  ☑ 209
# Q 164+10  T 174  ☑ 174
# Q 98+511  T 609  ☑ 609
# Q 876+523 T 1399 ☑ 1399
# Q 575+383 T 958  ☑ 958
# Q 50+723  T 773  ☑ 773
# Q 151+697 T 848  ☑ 848
# Q 60+163  T 223  ☑ 223
# Q 383+4   T 387  ☑ 387
#
# --------------------------------------------------
# Iteration 65
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 112s - loss: 0.0185 - acc: 0.9980 - val_loss: 0.0583 - val_acc: 0.9821
# Q 3+656   T 659  ☑ 659
# Q 924+43  T 967  ☑ 967
# Q 157+22  T 179  ☒ 189
# Q 77+481  T 558  ☑ 558
# Q 99+890  T 989  ☑ 989
# Q 777+749 T 1526 ☑ 1526
# Q 668+378 T 1046 ☑ 1046
# Q 44+334  T 378  ☑ 378
# Q 138+767 T 905  ☑ 905
# Q 64+78   T 142  ☑ 142
#
# --------------------------------------------------
# Iteration 66
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 105s - loss: 0.0160 - acc: 0.9988 - val_loss: 0.0589 - val_acc: 0.9816
# Q 373+9   T 382  ☑ 382
# Q 168+35  T 203  ☑ 203
# Q 893+54  T 947  ☑ 947
# Q 449+396 T 845  ☑ 845
# Q 970+159 T 1129 ☑ 1129
# Q 362+32  T 394  ☑ 394
# Q 519+71  T 590  ☑ 590
# Q 1+778   T 779  ☑ 779
# Q 635+22  T 657  ☑ 657
# Q 319+798 T 1117 ☑ 1117
#
# --------------------------------------------------
# Iteration 67
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 184s - loss: 0.0929 - acc: 0.9699 - val_loss: 0.1556 - val_acc: 0.9484
# Q 35+316  T 351  ☑ 351
# Q 523+3   T 526  ☑ 526
# Q 649+51  T 700  ☒ 600
# Q 27+44   T 71   ☒ 61
# Q 28+970  T 998  ☑ 998
# Q 929+570 T 1499 ☑ 1499
# Q 692+10  T 702  ☑ 702
# Q 655+33  T 688  ☑ 688
# Q 980+595 T 1575 ☒ 1576
# Q 126+841 T 967  ☑ 967
#
# --------------------------------------------------
# Iteration 68
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 229s - loss: 0.0433 - acc: 0.9888 - val_loss: 0.0553 - val_acc: 0.9835
# Q 527+318 T 845  ☑ 845
# Q 795+2   T 797  ☑ 797
# Q 30+867  T 897  ☑ 897
# Q 795+865 T 1660 ☑ 1660
# Q 30+954  T 984  ☑ 984
# Q 951+84  T 1035 ☑ 1035
# Q 129+2   T 131  ☑ 131
# Q 523+427 T 950  ☑ 950
# Q 625+16  T 641  ☑ 641
# Q 898+371 T 1269 ☑ 1269
#
# --------------------------------------------------
# Iteration 69
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 184s - loss: 0.0152 - acc: 0.9988 - val_loss: 0.0501 - val_acc: 0.9841
# Q 701+1   T 702  ☑ 702
# Q 72+636  T 708  ☑ 708
# Q 226+6   T 232  ☑ 232
# Q 215+367 T 582  ☑ 582
# Q 218+26  T 244  ☑ 244
# Q 133+30  T 163  ☑ 163
# Q 65+605  T 670  ☑ 670
# Q 6+449   T 455  ☑ 455
# Q 991+117 T 1108 ☑ 1108
# Q 52+402  T 454  ☑ 454
#
# --------------------------------------------------
# Iteration 70
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 311s - loss: 0.0128 - acc: 0.9993 - val_loss: 0.0498 - val_acc: 0.9844
# Q 294+347 T 641  ☑ 641
# Q 792+809 T 1601 ☑ 1601
# Q 394+9   T 403  ☑ 403
# Q 936+23  T 959  ☑ 959
# Q 949+83  T 1032 ☑ 1032
# Q 941+64  T 1005 ☑ 1005
# Q 952+923 T 1875 ☑ 1875
# Q 342+942 T 1284 ☑ 1284
# Q 28+355  T 383  ☑ 383
# Q 921+20  T 941  ☑ 941
#
# --------------------------------------------------
# Iteration 71
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 185s - loss: 0.0124 - acc: 0.9990 - val_loss: 0.0527 - val_acc: 0.9836
# Q 205+26  T 231  ☑ 231
# Q 606+475 T 1081 ☑ 1081
# Q 146+303 T 449  ☑ 449
# Q 970+93  T 1063 ☑ 1063
# Q 17+340  T 357  ☑ 357
# Q 24+696  T 720  ☑ 720
# Q 78+260  T 338  ☑ 338
# Q 578+11  T 589  ☑ 589
# Q 32+754  T 786  ☑ 786
# Q 402+91  T 493  ☑ 493
#
# --------------------------------------------------
# Iteration 72
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 253s - loss: 0.0123 - acc: 0.9989 - val_loss: 0.0521 - val_acc: 0.9848
# Q 636+806 T 1442 ☒ 1443
# Q 578+225 T 803  ☑ 803
# Q 635+742 T 1377 ☑ 1377
# Q 97+852  T 949  ☑ 949
# Q 60+770  T 830  ☑ 830
# Q 384+886 T 1270 ☑ 1270
# Q 318+31  T 349  ☑ 349
# Q 742+92  T 834  ☑ 834
# Q 900+222 T 1122 ☑ 1122
# Q 133+35  T 168  ☑ 168
#
# --------------------------------------------------
# Iteration 73
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 384s - loss: 0.0117 - acc: 0.9990 - val_loss: 0.0501 - val_acc: 0.9843
# Q 589+7   T 596  ☒ 696
# Q 112+7   T 119  ☑ 119
# Q 26+178  T 204  ☑ 204
# Q 10+305  T 315  ☑ 315
# Q 31+570  T 601  ☑ 601
# Q 580+757 T 1337 ☑ 1337
# Q 894+4   T 898  ☒ 998
# Q 501+2   T 503  ☑ 503
# Q 796+778 T 1574 ☑ 1574
# Q 90+959  T 1049 ☑ 1049
#
# --------------------------------------------------
# Iteration 74
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 368s - loss: 0.0269 - acc: 0.9933 - val_loss: 0.2511 - val_acc: 0.9200
# Q 974+57  T 1031 ☒ 1032
# Q 555+168 T 723  ☒ 724
# Q 44+87   T 131  ☑ 131
# Q 802+519 T 1321 ☑ 1321
# Q 94+849  T 943  ☒ 944
# Q 310+45  T 355  ☑ 355
# Q 71+23   T 94   ☑ 94
# Q 381+926 T 1307 ☒ 1308
# Q 570+66  T 636  ☑ 636
# Q 132+391 T 523  ☑ 523
#
# --------------------------------------------------
# Iteration 75
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 385s - loss: 0.0835 - acc: 0.9728 - val_loss: 0.1207 - val_acc: 0.9589
# Q 99+770  T 869  ☑ 869
# Q 8+481   T 489  ☑ 489
# Q 56+952  T 1008 ☑ 1008
# Q 973+33  T 1006 ☑ 1006
# Q 326+549 T 875  ☑ 875
# Q 774+81  T 855  ☑ 855
# Q 601+15  T 616  ☑ 616
# Q 32+500  T 532  ☑ 532
# Q 580+49  T 629  ☑ 629
# Q 6+86    T 92   ☑ 92
#
# --------------------------------------------------
# Iteration 76
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 147s - loss: 0.0199 - acc: 0.9962 - val_loss: 0.0506 - val_acc: 0.9841
# Q 87+87   T 174  ☑ 174
# Q 317+51  T 368  ☑ 368
# Q 300+913 T 1213 ☑ 1213
# Q 15+922  T 937  ☑ 937
# Q 45+176  T 221  ☑ 221
# Q 716+396 T 1112 ☑ 1112
# Q 172+932 T 1104 ☒ 1004
# Q 637+666 T 1303 ☑ 1303
# Q 537+83  T 620  ☑ 620
# Q 69+688  T 757  ☑ 757
#
# --------------------------------------------------
# Iteration 77
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 253s - loss: 0.0105 - acc: 0.9993 - val_loss: 0.0455 - val_acc: 0.9854
# Q 99+761  T 860  ☑ 860
# Q 897+662 T 1559 ☑ 1559
# Q 21+296  T 317  ☑ 317
# Q 40+822  T 862  ☑ 862
# Q 348+39  T 387  ☑ 387
# Q 324+803 T 1127 ☑ 1127
# Q 22+695  T 717  ☑ 717
# Q 963+0   T 963  ☑ 963
# Q 542+583 T 1125 ☑ 1125
# Q 33+471  T 504  ☑ 504
#
# --------------------------------------------------
# Iteration 78
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 245s - loss: 0.0089 - acc: 0.9995 - val_loss: 0.0446 - val_acc: 0.9864
# Q 342+331 T 673  ☑ 673
# Q 247+307 T 554  ☑ 554
# Q 50+50   T 100  ☒ 101
# Q 84+186  T 270  ☑ 270
# Q 894+66  T 960  ☒ 950
# Q 374+69  T 443  ☑ 443
# Q 1+646   T 647  ☑ 647
# Q 491+774 T 1265 ☑ 1265
# Q 980+96  T 1076 ☑ 1076
# Q 540+2   T 542  ☑ 542
#
# --------------------------------------------------
# Iteration 79
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 286s - loss: 0.0088 - acc: 0.9995 - val_loss: 0.0412 - val_acc: 0.9869
# Q 813+99  T 912  ☑ 912
# Q 862+76  T 938  ☑ 938
# Q 3+118   T 121  ☑ 121
# Q 838+33  T 871  ☑ 871
# Q 333+14  T 347  ☑ 347
# Q 507+52  T 559  ☑ 559
# Q 41+267  T 308  ☑ 308
# Q 332+446 T 778  ☑ 778
# Q 925+4   T 929  ☑ 929
# Q 79+985  T 1064 ☑ 1064
#
# --------------------------------------------------
# Iteration 80
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 186s - loss: 0.0078 - acc: 0.9996 - val_loss: 0.0416 - val_acc: 0.9876
# Q 856+51  T 907  ☑ 907
# Q 41+100  T 141  ☑ 141
# Q 88+52   T 140  ☑ 140
# Q 204+29  T 233  ☑ 233
# Q 78+711  T 789  ☑ 789
# Q 158+347 T 505  ☑ 505
# Q 840+62  T 902  ☑ 902
# Q 347+36  T 383  ☑ 383
# Q 190+519 T 709  ☑ 709
# Q 165+767 T 932  ☑ 932
#
# --------------------------------------------------
# Iteration 81
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 143s - loss: 0.0800 - acc: 0.9740 - val_loss: 0.2579 - val_acc: 0.9110
# Q 944+7   T 951  ☑ 951
# Q 607+374 T 981  ☑ 981
# Q 310+66  T 376  ☑ 376
# Q 19+479  T 498  ☑ 498
# Q 634+2   T 636  ☑ 636
# Q 843+2   T 845  ☑ 845
# Q 33+501  T 534  ☒ 535
# Q 76+766  T 842  ☑ 842
# Q 40+508  T 548  ☒ 539
# Q 666+536 T 1202 ☑ 1202
#
# --------------------------------------------------
# Iteration 82
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 137s - loss: 0.0510 - acc: 0.9853 - val_loss: 0.0629 - val_acc: 0.9783
# Q 79+349  T 428  ☑ 428
# Q 70+97   T 167  ☑ 167
# Q 711+91  T 802  ☒ 702
# Q 90+580  T 670  ☑ 670
# Q 91+2    T 93   ☒ 92
# Q 442+482 T 924  ☑ 924
# Q 11+783  T 794  ☑ 794
# Q 99+479  T 578  ☑ 578
# Q 171+80  T 251  ☑ 251
# Q 41+898  T 939  ☑ 939
#
# --------------------------------------------------
# Iteration 83
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 136s - loss: 0.0106 - acc: 0.9992 - val_loss: 0.0422 - val_acc: 0.9873
# Q 47+576  T 623  ☑ 623
# Q 952+284 T 1236 ☑ 1236
# Q 26+609  T 635  ☑ 635
# Q 779+744 T 1523 ☑ 1523
# Q 921+626 T 1547 ☑ 1547
# Q 297+34  T 331  ☒ 431
# Q 7+903   T 910  ☑ 910
# Q 44+899  T 943  ☑ 943
# Q 345+652 T 997  ☑ 997
# Q 954+23  T 977  ☑ 977
#
# --------------------------------------------------
# Iteration 84
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 214s - loss: 0.0076 - acc: 0.9997 - val_loss: 0.0393 - val_acc: 0.9889
# Q 968+744 T 1712 ☑ 1712
# Q 328+87  T 415  ☑ 415
# Q 27+106  T 133  ☑ 133
# Q 620+5   T 625  ☑ 625
# Q 840+479 T 1319 ☑ 1319
# Q 550+488 T 1038 ☑ 1038
# Q 538+35  T 573  ☑ 573
# Q 740+690 T 1430 ☑ 1430
# Q 466+57  T 523  ☑ 523
# Q 163+881 T 1044 ☑ 1044
#
# --------------------------------------------------
# Iteration 85
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 123s - loss: 0.0067 - acc: 0.9998 - val_loss: 0.0395 - val_acc: 0.9879
# Q 198+289 T 487  ☑ 487
# Q 667+688 T 1355 ☑ 1355
# Q 102+10  T 112  ☑ 112
# Q 754+1   T 755  ☑ 755
# Q 36+166  T 202  ☑ 202
# Q 387+75  T 462  ☑ 462
# Q 484+82  T 566  ☑ 566
# Q 238+240 T 478  ☑ 478
# Q 74+13   T 87   ☑ 87
# Q 93+858  T 951  ☑ 951
#
# --------------------------------------------------
# Iteration 86
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 192s - loss: 0.0067 - acc: 0.9997 - val_loss: 0.0403 - val_acc: 0.9874
# Q 537+377 T 914  ☑ 914
# Q 165+34  T 199  ☒ 299
# Q 35+587  T 622  ☑ 622
# Q 52+452  T 504  ☑ 504
# Q 990+84  T 1074 ☑ 1074
# Q 94+859  T 953  ☑ 953
# Q 20+84   T 104  ☑ 104
# Q 270+844 T 1114 ☑ 1114
# Q 875+76  T 951  ☑ 951
# Q 265+137 T 402  ☑ 402
#
# --------------------------------------------------
# Iteration 87
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 143s - loss: 0.0062 - acc: 0.9997 - val_loss: 0.0369 - val_acc: 0.9884
# Q 694+958 T 1652 ☑ 1652
# Q 165+662 T 827  ☑ 827
# Q 114+889 T 1003 ☒ 1004
# Q 125+26  T 151  ☑ 151
# Q 95+355  T 450  ☑ 450
# Q 19+941  T 960  ☑ 960
# Q 110+117 T 227  ☑ 227
# Q 262+5   T 267  ☑ 267
# Q 591+5   T 596  ☑ 596
# Q 46+216  T 262  ☑ 262
#
# --------------------------------------------------
# Iteration 88
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 145s - loss: 0.0059 - acc: 0.9997 - val_loss: 0.0392 - val_acc: 0.9878
# Q 189+59  T 248  ☑ 248
# Q 553+934 T 1487 ☑ 1487
# Q 404+584 T 988  ☑ 988
# Q 46+888  T 934  ☑ 934
# Q 858+40  T 898  ☑ 898
# Q 448+27  T 475  ☑ 475
# Q 62+72   T 134  ☑ 134
# Q 82+610  T 692  ☑ 692
# Q 27+371  T 398  ☑ 398
# Q 250+633 T 883  ☑ 883
#
# --------------------------------------------------
# Iteration 89
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 172s - loss: 0.0068 - acc: 0.9993 - val_loss: 0.0458 - val_acc: 0.9853
# Q 727+142 T 869  ☑ 869
# Q 410+18  T 428  ☑ 428
# Q 587+829 T 1416 ☑ 1416
# Q 92+250  T 342  ☑ 342
# Q 404+447 T 851  ☑ 851
# Q 669+181 T 850  ☑ 850
# Q 81+316  T 397  ☑ 397
# Q 24+973  T 997  ☑ 997
# Q 114+48  T 162  ☑ 162
# Q 95+28   T 123  ☑ 123
#
# --------------------------------------------------
# Iteration 90
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 133s - loss: 0.0108 - acc: 0.9979 - val_loss: 0.0772 - val_acc: 0.9751
# Q 798+35  T 833  ☑ 833
# Q 15+87   T 102  ☒ 901
# Q 41+698  T 739  ☑ 739
# Q 74+977  T 1051 ☑ 1051
# Q 51+62   T 113  ☑ 113
# Q 12+314  T 326  ☑ 326
# Q 975+93  T 1068 ☑ 1068
# Q 411+704 T 1115 ☑ 1115
# Q 64+919  T 983  ☑ 983
# Q 6+386   T 392  ☑ 392
#
# --------------------------------------------------
# Iteration 91
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 156s - loss: 0.1219 - acc: 0.9604 - val_loss: 0.0651 - val_acc: 0.9801
# Q 423+50  T 473  ☑ 473
# Q 70+796  T 866  ☑ 866
# Q 675+48  T 723  ☑ 723
# Q 144+63  T 207  ☑ 207
# Q 86+624  T 710  ☑ 710
# Q 82+961  T 1043 ☑ 1043
# Q 64+97   T 161  ☑ 161
# Q 40+466  T 506  ☒ 406
# Q 10+764  T 774  ☑ 774
# Q 18+388  T 406  ☑ 406
#
# --------------------------------------------------
# Iteration 92
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 155s - loss: 0.0134 - acc: 0.9982 - val_loss: 0.0427 - val_acc: 0.9855
# Q 42+582  T 624  ☑ 624
# Q 190+24  T 214  ☑ 214
# Q 37+590  T 627  ☑ 627
# Q 865+313 T 1178 ☑ 1178
# Q 557+39  T 596  ☒ 696
# Q 241+68  T 309  ☑ 309
# Q 888+358 T 1246 ☑ 1246
# Q 660+517 T 1177 ☑ 1177
# Q 770+1   T 771  ☑ 771
# Q 22+69   T 91   ☑ 91
#
# --------------------------------------------------
# Iteration 93
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 129s - loss: 0.0066 - acc: 0.9998 - val_loss: 0.0390 - val_acc: 0.9880
# Q 403+67  T 470  ☑ 470
# Q 74+917  T 991  ☑ 991
# Q 61+249  T 310  ☑ 310
# Q 972+7   T 979  ☑ 979
# Q 87+557  T 644  ☑ 644
# Q 560+43  T 603  ☑ 603
# Q 357+733 T 1090 ☑ 1090
# Q 534+79  T 613  ☑ 613
# Q 133+50  T 183  ☑ 183
# Q 294+501 T 795  ☒ 895
#
# --------------------------------------------------
# Iteration 94
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 137s - loss: 0.0056 - acc: 0.9999 - val_loss: 0.0375 - val_acc: 0.9875
# Q 28+569  T 597  ☑ 597
# Q 61+846  T 907  ☑ 907
# Q 53+432  T 485  ☑ 485
# Q 0+621   T 621  ☑ 621
# Q 984+792 T 1776 ☑ 1776
# Q 441+164 T 605  ☑ 605
# Q 945+799 T 1744 ☑ 1744
# Q 15+765  T 780  ☑ 780
# Q 69+888  T 957  ☑ 957
# Q 4+224   T 228  ☑ 228
#
# --------------------------------------------------
# Iteration 95
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 114s - loss: 0.0050 - acc: 0.9999 - val_loss: 0.0353 - val_acc: 0.9880
# Q 808+365 T 1173 ☑ 1173
# Q 265+116 T 381  ☑ 381
# Q 25+535  T 560  ☑ 560
# Q 775+53  T 828  ☑ 828
# Q 428+834 T 1262 ☑ 1262
# Q 509+70  T 579  ☑ 579
# Q 138+950 T 1088 ☑ 1088
# Q 27+850  T 877  ☑ 877
# Q 7+563   T 570  ☑ 570
# Q 20+614  T 634  ☑ 634
#
# --------------------------------------------------
# Iteration 96
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 50s - loss: 0.0046 - acc: 0.9998 - val_loss: 0.0357 - val_acc: 0.9901
# Q 703+30  T 733  ☑ 733
# Q 63+26   T 89   ☑ 89
# Q 34+989  T 1023 ☑ 1023
# Q 820+277 T 1097 ☑ 1097
# Q 89+124  T 213  ☑ 213
# Q 971+78  T 1049 ☑ 1049
# Q 78+941  T 1019 ☑ 1019
# Q 296+490 T 786  ☑ 786
# Q 912+43  T 955  ☑ 955
# Q 697+505 T 1202 ☑ 1202
#
# --------------------------------------------------
# Iteration 97
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 110s - loss: 0.0045 - acc: 0.9999 - val_loss: 0.0378 - val_acc: 0.9875
# Q 373+68  T 441  ☑ 441
# Q 820+543 T 1363 ☑ 1363
# Q 169+75  T 244  ☑ 244
# Q 77+219  T 296  ☑ 296
# Q 549+267 T 816  ☑ 816
# Q 865+820 T 1685 ☑ 1685
# Q 335+83  T 418  ☑ 418
# Q 670+967 T 1637 ☑ 1637
# Q 376+40  T 416  ☑ 416
# Q 109+907 T 1016 ☒ 1017
#
# --------------------------------------------------
# Iteration 98
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 91s - loss: 0.0267 - acc: 0.9922 - val_loss: 0.3067 - val_acc: 0.9156
# Q 426+29  T 455  ☑ 455
# Q 853+198 T 1051 ☑ 1051
# Q 9+156   T 165  ☑ 165
# Q 583+391 T 974  ☒ 965
# Q 26+529  T 555  ☑ 555
# Q 579+3   T 582  ☒ 583
# Q 97+691  T 788  ☒ 888
# Q 480+71  T 551  ☑ 551
# Q 500+370 T 870  ☒ 770
# Q 38+596  T 634  ☑ 634
#
# --------------------------------------------------
# Iteration 99
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
#  - 150s - loss: 0.1097 - acc: 0.9662 - val_loss: 0.0556 - val_acc: 0.9821
# Q 952+7   T 959  ☑ 959
# Q 73+47   T 120  ☑ 120
# Q 570+66  T 636  ☑ 636
# Q 914+173 T 1087 ☑ 1087
# Q 70+40   T 110  ☑ 110
# Q 49+152  T 201  ☑ 201
# Q 183+634 T 817  ☑ 817
# Q 541+846 T 1387 ☑ 1387
# Q 46+561  T 607  ☑ 607
# Q 38+650  T 688  ☑ 688

# %% [markdown]
# ## test

# %%
score, acc = model.evaluate(testData, testTarget)
print('Test score:', score)
print('Test accuracy:', acc)
